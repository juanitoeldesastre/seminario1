# %% [markdown]
# ## Regresión Lineal Simple
# La **Regresión Lineal Simple** es un método estadístico que modela la relación entre una variable dependiente (resultado) y una variable independiente (predicción) mediante una línea recta. La ecuación general para una regresión lineal simple es:
#
# \[
# y = mx + b
# \]
#
# donde:
# - **📊 y** es la variable dependiente.
# - **📈 m** representa la pendiente de la línea.
# - **📉 x** es la variable independiente.
# - **⚓ b** es la intersección de la línea en el eje y.

# %%
# Importar las librerías necesarias
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Datos de ejemplo: cantidad de ventas (X) y precio del producto (y)
X = np.array([[1], [2], [3], [4], [5]]) # Cantidad de ventas
y = np.array([10, 15, 20, 25, 30]) # Precio del producto

# Crear el modelo de regresión lineal
model = LinearRegression()
model.fit(X, y)

# Hacer predicciones
y_pred = model.predict(X)

# Visualizar la línea de regresión
plt.scatter(X, y, color='blue', label='Datos Reales') # Puntos de datos
plt.plot(X, y_pred, color='red', label='Línea de Regresión') # Línea deregresión
plt.title('Regresión Lineal Simple')
plt.xlabel('Cantidad de Ventas')
plt.ylabel('Precio del Producto')
plt.legend()
plt.show()

# Coeficientes
print(f'Intercepto: {model.intercept_}')
print(f'Pendiente: {model.coef_[0]}')
# Out:
# Intercepto: 5.0000000000000036
# Pendiente: 4.999999999999999

# %% [markdown]
# ## Ejercicio 1
#
# Dado un conjunto de datos que relaciona las horas de estudio con las calificaciones de los estudiantes, crea un modelo de regresión lineal simple y predice la calificación para 4.5 horas de estudio.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# data
X = np.array([[1], [1.5], [2], [2.3], [3.2], [4], [5], [7.6], [8], [10]])
y = np.array([2, 3, 5, 7, 8.5, 12, 13.5, 14, 18, 19.8])

# creating the Linear Regression model
model = LinearRegression()
model.fit(X, y)

# predictions
calif_pred = model.predict([[4.5]])
print(f'La calificación para 4.5 horas de estudio es: {calif_pred[0]}')

# visualizing the data
plt.scatter(X, y, color='blue', label='Datos Registrados Reales')
plt.plot(X, model.predict(X), color='red', label='Línea de Regresión')
plt.title('Regresión Lineal Simple Ejercicio 01')
plt.xlabel('Horas de estudio')
plt.ylabel('Calificaciones')
plt.legend()
plt.show()

# coefficients
print(f'Intercepto: {model.intercept_}')
print(f'Pendiente: {model.coef_[0]}')
# Out:
# La calificación para 4.5 horas de estudio es: 10.356289250092352
# Intercepto: 1.7737486147026242
# Pendiente: 1.9072312523088286

# %% [markdown]
# ## Ejercicio 2
#
# Usa datos de la temperatura y el consumo de helados para construir un modelo de regresión lineal simple. Predice el consumo de helados a una temperatura de 30 grados.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Crear los datos de temperatura y consumo de helados
X = np.array([[10], [13], [17], [20], [22], [28], [36], [38], [40], [44]])  # Temperatura
y = np.array([500, 800, 1186, 3000, 3652, 3856, 4050, 5168, 6002, 7010])   # Consumo de helados

# Crear el modelo
model = LinearRegression()
model.fit(X, y)

# Hacer predicciones
consumo_pred = model.predict([[30]])
print(f'El consumo de helados a una temperatura de 30 grados es: {consumo_pred[0]}')

# Visualizar la línea de regresión
plt.scatter(X, y, color='blue', label='Datos Reales')
plt.plot(X, model.predict(X), color='red', label='Regresión Lineal')
plt.xlabel('Temperatura')
plt.ylabel('Consumo de helados')
plt.legend()
plt.show()

# Valores de los coeficientes
print(f'Intercepto: {model.intercept_}')
print(f'Pendiente: {model.coef_[0]}')
# Out:
# El consumo de helados a una temperatura de 30 grados es: 4081.5386480751745
# Intercepto: -1160.386177629583
# Pendiente: 174.7308275234919

# %% [markdown]
# ## Ejercicio 3
#
# Crea un modelo de regresión lineal simple utilizando el número de
# seguidores de un influencer y las interacciones (likes, comentarios) en sus
# publicaciones. Predice las interacciones para un influencer con 20,000 seguidores.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# crear datos de ejemplo de seguidores (x) e interacciones (y)
x = np.array([[1000000], [3000000], [10000000], [21000000], [33000000], [50000000]])  # seguidores
y = np.array([159753, 183957, 258963, 295741, 389472, 807456])  # interacciones

# modelo de regresión lineal
model = LinearRegression()
model.fit(x, y)

# Hacer la predicción
interacciones_pred = model.predict(np.array([[34100000]]))
pred_value = interacciones_pred[0]
print(f'Predicción de interacciones para 34,100,000 seguidores: {pred_value}')

# visualizar la línea de regresión
plt.scatter(x, y, color='blue', label='Datos Reales')  # Datos reales
plt.plot(x, model.predict(x), color='red', label='Línea de Regresión')  # Línea de regresión
plt.xlabel('Seguidores')
plt.ylabel('Interacciones')
plt.title('Relación entre Seguidores e Interacciones')
plt.legend()
plt.show()

# Valores de los coeficientes
print(f'Intercepto: {model.intercept_}')
print(f'Pendiente: {model.coef_[0]}')
# Out:
# Predicción de interacciones para 34,100,000 seguidores: 520018.274184683
# Intercepto: 116501.22224257977
# Pendiente: 0.011833344631733233
