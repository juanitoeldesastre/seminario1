# %%
#Analisis de datos
#Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
#cargar los datos de ventas de la heladeria
heladeria_df = pd.read_csv('Heladeria.csv')
 
#Mostrar las primeras filas del dataframe
print(heladeria_df.head())
 
#calcular el promedio de ventas por sabor de helado
promedio_ventas_helados = heladeria_df[['Chocolate','Fresa','Vainilla','Mango']].mean()
 
#Mostrar los resultados
print('Promedio de ventas por producto')
print(promedio_ventas_helados)
 
#identificar le producto con mayor venta
producto_recomendado = promedio_ventas_helados.idxmax()
print("\n")
print(f'Se recomienda invertir mas en el producto: {producto_recomendado} para octubre del 2024')
 
#ingresamos una grafica de los productos / barras
plt.figure(figsize=(8,6))
promedio_ventas_helados.plot(kind='bar',color=['brown','pink','blue','orange'])
plt.title('Promedio de ventas por producto en Heladeria')
plt.xlabel('Sabores')
plt.ylabel('Promedio de ventas')
plt.xticks(rotation=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 8
#       5 import matplotlib.pyplot as plt
#       7 #cargar los datos de ventas de la heladeria
# ----> 8 heladeria_df = pd.read_csv('Heladeria.csv')
#      10 #Mostrar las primeras filas del dataframe
#      11 print(heladeria_df.head())
#
# ...

# %%
# Analisis de datos
# Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Cargar los datos de ventas de la tienda de ropa
clothing_store_df = pd.read_csv('Clothing_store.csv')

# Mostrar las primeras filas del dataframe
print(clothing_store_df.head())

promedio_ventas_clothing_store = clothing_store_df[['Camisas', 'Pantalones', 'Vestidos', 'Blusas']].mean()
# Mostrar los resultados
print('Promedio de ventas por tipo de ropa:')
print(promedio_ventas_clothing_store)

# Identificar el producto con mayor venta
producto_recomendado = promedio_ventas_clothing_store.idxmax()
print("\n")
print(f'Se recomienda invertir más en el producto: {producto_recomendado} para octubre del 2024')

# Graficar las ventas promedio por tipo de producto
plt.figure(figsize=(8,6))
promedio_ventas_clothing_store.plot(kind='bar', color=['brown', 'pink', 'blue', 'orange'])
plt.title('Promedio de ventas por producto en tienda de ropa')
plt.xlabel('Tipo de producto')
plt.ylabel('Promedio de ventas')
plt.xticks(rotation=0)
plt.show()
# Out:
#         Meses  Camisas  Pantalones  Vestidos  Blusas
# 0  2020-01-31     1262        3961      4680    1127
# 1  2020-02-29     2787        2919      3331    3065
# 2  2020-03-31     3191        1877      3926    2816
# 3  2020-04-30     3393        1337      1959    2758
# 4  2020-05-31     1623        4777      2504    3613
# Promedio de ventas por tipo de ropa:
# Camisas       2950.066667
# Pantalones    2886.866667
# Vestidos      2984.955556
# Blusas        3022.711111
# dtype: float64
#
#
# Se recomienda invertir más en el producto: Blusas para octubre del 2024

# %%
#Analisis de datos
#Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
#cargar los datos de ventas de la heladeria
restaurante_df = pd.read_csv('Restaurante.csv')
 
print(restaurante_df.head())
 
promedio_ventas_restaurante = restaurante_df[['Pasta','Pizza','Ensalada','Sushi']].mean()
 
#Mostrar los resultados
print('Promedio de ventas por producto:')
print(promedio_ventas_restaurante)
 
#identificar le producto con mayor venta
producto_recomendado = promedio_ventas_restaurante.idxmax()
print("\n")
print(f'Se recomienda invertir mas en el producto: {producto_recomendado} para octubre del 2024')
 
#ingresamos una grafica de los productos / barras
plt.figure(figsize=(8,6))
promedio_ventas_helados.plot(kind='bar',color=['brown','pink','blue','yellow','green'])
plt.title('Promedio de ventas por producto en Restaurante')
plt.xlabel('Sabores')
plt.ylabel('Promedio de ventas')
plt.xticks(rotation=0)
plt.show()
# Out:
#         Meses  Pasta  Pizza  Ensalada  Sushi
# 0  2020-01-31   3690   4060      4763   4908
# 1  2020-02-29   4840   3693      2136   3931
# 2  2020-03-31   2028   1795      2853   4681
# 3  2020-04-30   4289   2051      2520   1197
# 4  2020-05-31   1502   2643      3489   4029
# Promedio de ventas por producto:
# Pasta       3097.844444
# Pizza       3110.555556
# Ensalada    2957.155556
# Sushi       3150.222222
# dtype: float64
#
#
# Se recomienda invertir mas en el producto: Sushi para octubre del 2024

# %%
#Analisis de datos
#Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
#cargar los datos de ventas de la heladeria
libreria_df = pd.read_csv('Libreria.csv')
 
#Mostrar las primeras filas del dataframe
print(libreria_df.head())
 
#calcular el promedio de ventas por sabor de helado
promedio_ventas_libreria = libreria_df[['Ficcion','No Ficcion','Historia','Cultura']].mean()
 
#Mostrar los resultados
print('Promedio de ventas por producto')
print(promedio_ventas_libreria)
 
#identificar le producto con mayor venta
producto_recomendado = promedio_ventas_libreria.idxmax()
print("\n")
print(f'Se recomienda invertir mas en el producto: {producto_recomendado} para octubre del 2024')
 
#ingresamos una grafica de los productos / barras
plt.figure(figsize=(8,6))
promedio_ventas_helados.plot(kind='bar',color=['brown','pink','blue','orange'])
plt.title('Promedio de ventas por producto en Libreria')
plt.xlabel('Categoria')
plt.ylabel('Promedio de ventas')
plt.xticks(rotation=0)
plt.show()
# Out:
#         Meses  Ficcion  No Ficcion  Historia  Cultura
# 0  2020-01-31     1399        4421      4343     4294
# 1  2020-02-29     3701        1046      2212     4977
# 2  2020-03-31     1971        3914      1703     3809
# 3  2020-04-30     2906        3870      2470     4730
# 4  2020-05-31     3518        3983      1580     3489
# Promedio de ventas por producto
# Ficcion       2978.688889
# No Ficcion    2826.111111
# Historia      3068.577778
# Cultura       3222.400000
# dtype: float64
#
#
# Se recomienda invertir mas en el producto: Cultura para octubre del 2024

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Cargar los datos de la heladería
heladeria_df = pd.read_csv('Heladeria.csv')

# Seleccionar solo las columnas de ventas
X = heladeria_df[['Chocolate', 'Fresa', 'Vainilla', 'Mango']].values

# Escalar los datos entre 0 y 1
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Crear las etiquetas (Y) con los mismos datos de las ventas, desplazado en el tiempo
Y = np.roll(X_scaled, -1, axis=0)

# Separar los datos de entrenamiento y validación
X_train, Y_train = X_scaled[:-1], Y[:-1]

# Definir el modelo
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))  # Corrección: 'activation' en vez de 'actviation'
model.add(Dense(4, activation='linear'))

# Compilar el modelo
model.compile(optimizer='adam', loss='mean_squared_error')

# Entrenar el modelo
history = model.fit(X_train, Y_train, epochs=200, batch_size=16, verbose=1)

# Predicción para las ventas del 2025
prediccion_2025 = model.predict(X_train[-1].reshape(1, -1))
ventas_2025 = scaler.inverse_transform(prediccion_2025)  # Desescalar los valores

# Mostrar las predicciones de ventas del 2025
productos = ['Chocolate', 'Fresa', 'Vainilla', 'Mango']
ventas_2025 = ventas_2025.flatten()
for i, producto in enumerate(productos):
    print(f'Predicción de ventas para {producto} en 2025: {ventas_2025[i]:.2f}')
    
#agregamos grafica
plt.figure(figsize=(8,6))
plt.bar(productos, ventas_2025, color=['brown','pink','beige','orange'] )
plt.title('Promedio de ventas por producto en Heladeria para el 2025')
plt.xlabel('Sabores')
plt.ylabel('Promedio Proyectadas')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Cargar los datos de la heladería
heladeria_df = pd.read_csv('Clothing_Store.csv')

# Seleccionar solo las columnas de ventas
X = heladeria_df[['Camisas', 'Pantalones', 'Vestidos', 'Blusas']].values

# Escalar los datos entre 0 y 1
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Crear las etiquetas (Y) con los mismos datos de las ventas, desplazado en el tiempo
Y = np.roll(X_scaled, -1, axis=0)

# Separar los datos de entrenamiento y validación
X_train, Y_train = X_scaled[:-1], Y[:-1]

# Definir el modelo
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))  # Corrección: 'activation' en vez de 'actviation'
model.add(Dense(4, activation='linear'))

# Compilar el modelo
model.compile(optimizer='adam', loss='mean_squared_error')

# Entrenar el modelo
history = model.fit(X_train, Y_train, epochs=200, batch_size=16, verbose=1)

# Predicción para las ventas del 2025
prediccion_2025 = model.predict(X_train[-1].reshape(1, -1))
ventas_2025 = scaler.inverse_transform(prediccion_2025)  # Desescalar los valores

# Mostrar las predicciones de ventas del 2025
productos = ['Camisas', 'Pantalones', 'Vestidos', 'Blusas']
ventas_2025 = ventas_2025.flatten()
for i, producto in enumerate(productos):
    print(f'Predicción de ventas para {producto} en 2025: {ventas_2025[i]:.2f}')
    
#agregamos grafica
plt.figure(figsize=(8,6))
plt.bar(productos, ventas_2025, color=['brown','pink','beige','orange'] )
plt.title('Promedio de ventas por producto en tienda de ropa para el 2025')
plt.xlabel('Sabores')
plt.ylabel('Promedio Proyectadas')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Cargar los datos de la heladería
heladeria_df = pd.read_csv('Restaurante.csv')

# Seleccionar solo las columnas de ventas
X = heladeria_df[['Chocolate', 'Fresa', 'Vainilla', 'Mango']].values

# Escalar los datos entre 0 y 1
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Crear las etiquetas (Y) con los mismos datos de las ventas, desplazado en el tiempo
Y = np.roll(X_scaled, -1, axis=0)

# Separar los datos de entrenamiento y validación
X_train, Y_train = X_scaled[:-1], Y[:-1]

# Definir el modelo
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))  # Corrección: 'activation' en vez de 'actviation'
model.add(Dense(4, activation='linear'))

# Compilar el modelo
model.compile(optimizer='adam', loss='mean_squared_error')

# Entrenar el modelo
history = model.fit(X_train, Y_train, epochs=200, batch_size=16, verbose=1)

# Predicción para las ventas del 2025
prediccion_2025 = model.predict(X_train[-1].reshape(1, -1))
ventas_2025 = scaler.inverse_transform(prediccion_2025)  # Desescalar los valores

# Mostrar las predicciones de ventas del 2025
productos = ['Chocolate', 'Fresa', 'Vainilla', 'Mango']
ventas_2025 = ventas_2025.flatten()
for i, producto in enumerate(productos):
    print(f'Predicción de ventas para {producto} en 2025: {ventas_2025[i]:.2f}')
    
#agregamos grafica
plt.figure(figsize=(8,6))
plt.bar(productos, ventas_2025, color=['brown','pink','beige','orange'] )
plt.title('Promedio de ventas por producto en Heladeria para el 2025')
plt.xlabel('Sabores')
plt.ylabel('Promedio Proyectadas')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Cargar los datos de la heladería
heladeria_df = pd.read_csv('Libreria.csv')

# Seleccionar solo las columnas de ventas
X = heladeria_df[['Chocolate', 'Fresa', 'Vainilla', 'Mango']].values

# Escalar los datos entre 0 y 1
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Crear las etiquetas (Y) con los mismos datos de las ventas, desplazado en el tiempo
Y = np.roll(X_scaled, -1, axis=0)

# Separar los datos de entrenamiento y validación
X_train, Y_train = X_scaled[:-1], Y[:-1]

# Definir el modelo
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(64, activation='relu'))  # Corrección: 'activation' en vez de 'actviation'
model.add(Dense(4, activation='linear'))

# Compilar el modelo
model.compile(optimizer='adam', loss='mean_squared_error')

# Entrenar el modelo
history = model.fit(X_train, Y_train, epochs=200, batch_size=16, verbose=1)

# Predicción para las ventas del 2025
prediccion_2025 = model.predict(X_train[-1].reshape(1, -1))
ventas_2025 = scaler.inverse_transform(prediccion_2025)  # Desescalar los valores

# Mostrar las predicciones de ventas del 2025
productos = ['Chocolate', 'Fresa', 'Vainilla', 'Mango']
ventas_2025 = ventas_2025.flatten()
for i, producto in enumerate(productos):
    print(f'Predicción de ventas para {producto} en 2025: {ventas_2025[i]:.2f}')
    
#agregamos grafica
plt.figure(figsize=(8,6))
plt.bar(productos, ventas_2025, color=['brown','pink','beige','orange'] )
plt.title('Promedio de ventas por producto en Heladeria para el 2025')
plt.xlabel('Sabores')
plt.ylabel('Promedio Proyectadas')
plt.show()
